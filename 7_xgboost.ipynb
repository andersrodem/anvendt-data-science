# %% [markdown]
# # Regular version

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# Load the preprocessed dataset
file_path = 'preprocessed_dataset.csv'
data = pd.read_csv(file_path)

# Print basic information about the dataset
print("Dataset shape:", data.shape)
print("\nFeatures:", data.columns.tolist())
print("\nData types:\n", data.dtypes)
print("\nData sample:\n", data.head())

# Ensure data is sorted by date
data = data.sort_values('date')

# Split the data into features (X) and target variable (y)
X = data.drop(columns=['spot_price', 'date'])
y = data['spot_price']

# Print feature statistics
print("\nFeature statistics:")
print(X.describe())

# Print target variable statistics
print("\nTarget variable statistics:")
print(y.describe())

# TimeSeriesSplit for expanding window cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Initialize XGBoost model
model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Store results of each fold
fold_results = []

# Perform expanding window cross-validation
for fold, (train_index, test_index) in enumerate(tscv.split(X), 1):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Train the model on the expanding training set
    model.fit(X_train, y_train)
    
    # Predict on the test set for this fold
    y_pred = model.predict(X_test)
    
    # Calculate RMSE (Root Mean Squared Error) for this fold
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    
    # Store the RMSE result
    fold_results.append(rmse)
    
    print(f"\nFold {fold}:")
    print(f"Train set size: {len(X_train)}, Test set size: {len(X_test)}")
    print(f"RMSE: {rmse:.4f}")

# Output the RMSE results for each fold
print("\nRMSE for each fold:", [f"{rmse:.4f}" for rmse in fold_results])
print(f"Average RMSE across folds: {np.mean(fold_results):.4f}")

# Use the last 20% of the data for final testing
test_size = int(0.2 * len(X))
X_train, X_test = X.iloc[:-test_size], X.iloc[-test_size:]
y_train, y_test = y.iloc[:-test_size], y.iloc[-test_size:]

# Train the final model
final_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
final_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = final_model.predict(X_test)

# Calculate and print the final RMSE
final_rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f"\nFinal RMSE on test set: {final_rmse:.4f}")

# Print feature importance
feature_importance = pd.DataFrame({'feature': X.columns, 'importance': final
# Out:
# Requirement already satisfied: xgboost in /Users/andersrodem/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy in /Users/andersrodem/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from xgboost) (2.0.0)
# Requirement already satisfied: scipy in /Users/andersrodem/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from xgboost) (1.14.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# RMSE for each fold: [np.float64(5.32152323490936), np.float64(0.6092211835903061), np.float64(0.16515569767849061), np.float64(1.3764184943064073), np.float64(2.486172096681458)]
# Average RMSE across folds: 1.9916981414332047
# Final RMSE: 1.01285968309676

# %% [markdown]
# # Hyperparameter optimization with Optuna

# %%
import optuna
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from tqdm import tqdm
import warnings
from pprint import pprint

# Suppress warnings
warnings.filterwarnings("ignore")

# Define categorical feature groups
categorical_groups = {
    'day_of_week': ['day_of_week_1', 'day_of_week_2', 'day_of_week_3', 'day_of_week_4', 'day_of_week_5', 'day_of_week_6'],
    'is_weekend': ['is_weekend_1'],
    'month': ['month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12'],
    'year': ['year_2017', 'year_2018'],
    'season': ['season_Spring', 'season_Summer', 'season_Winter']
}

# Define the objective function for Optuna
def objective(trial):
    # Suggest values for hyperparameters
    param = {
        'objective': 'reg:squarederror',
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'lambda': trial.suggest_float('lambda', 0, 5),
    }
    
    # Suggest whether to include each feature group or not
    selected_features = []
    for group, features in categorical_groups.items():
        if trial.suggest_categorical(f"group_{group}", [0, 1]) == 1:
            selected_features.extend(features)
    
    # Suggest whether to include each non-categorical feature or not
    non_categorical_features = [col for col in X.columns if col not in [item for sublist in categorical_groups.values() for item in sublist]]
    for feature in non_categorical_features:
        if trial.suggest_categorical(f"feature_{feature}", [0, 1]) == 1:
            selected_features.append(feature)

    # If no feature is selected, return a high loss value
    if len(selected_features) == 0:
        return float('inf')

    # Select the features that are chosen by Optuna
    X_selected = X[selected_features]

    # TimeSeriesSplit for cross-validation
    tscv = TimeSeriesSplit(n_splits=5)
    rmse_list = []

    # Perform cross-validation with expanding window
    for train_index, test_index in tscv.split(X_selected):
        X_train, X_test = X_selected.iloc[train_index], X_selected.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Train the XGBoost model
        model = xgb.XGBRegressor(**param)
        model.fit(X_train, y_train)

        # Predict and evaluate the model
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        rmse_list.append(rmse)

    # Return the average RMSE across the folds
    return sum(rmse_list) / len(rmse_list)

# Create the Optuna study
study = optuna.create_study(direction='minimize')

# Wrap the optimization process in tqdm to track progress
n_trials = 50
with tqdm(total=n_trials, desc="Optimizing") as pbar:
    def callback(study, trial):
        pbar.update(1)
    
    study.optimize(objective, n_trials=n_trials, callbacks=[callback])

# Output the best trial and hyperparameters, including the selected features
print("\nBest trial RMSE:", study.best_trial.value)
print("\nBest hyperparameters:")
pprint(study.best_trial.params)

# Get the list of selected features from the best trial
best_trial = study.best_trial
selected_features = []
for group, features in categorical_groups.items():
    if best_trial.params[f"group_{group}"] == 1:
        selected_features.extend(features)
non_categorical_features = [col for col in X.columns if col not in [item for sublist in categorical_groups.values() for item in sublist]]
for feature in non_categorical_features:
    if best_trial.params[f"feature_{feature}"] == 1:
        selected_features.append(feature)
print("\nSelected features:", selected_features)
# Out:
# [I 2024-10-18 14:24:42,461] A new study created in memory with name: no-name-b88a42bc-2b11-469a-b09f-c03e918c6e51
# Optimizing:   0%|          | 0/50 [00:00<?, ?it/s][I 2024-10-18 14:24:44,546] Trial 0 finished with value: 2.8786128840652245 and parameters: {'n_estimators': 344, 'max_depth': 9, 'learning_rate': 0.016571018032323873, 'subsample': 0.615944171054639, 'colsample_bytree': 0.8598693719553465, 'min_child_weight': 10, 'gamma': 2.057455352005647, 'lambda': 2.9324414503174867, 'group_day_of_week': 0, 'group_is_weekend': 0, 'group_month': 1, 'group_year': 1, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 1, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 0, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 1, 'feature_Max_Wind': 0, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 0, 'feature_Snow_Depth': 1, 'feature_year': 0, 'feature_month': 1, 'feature_day': 0, 'feature_hour': 0}. Best is trial 0 with value: 2.8786128840652245.
# Optimizing:   2%|▏         | 1/50 [00:02<01:42,  2.08s/it][I 2024-10-18 14:24:45,256] Trial 1 finished with value: 2.783324445499681 and parameters: {'n_estimators': 261, 'max_depth': 9, 'learning_rate': 0.2778291964773248, 'subsample': 0.5156783360429489, 'colsample_bytree': 0.6268059024089645, 'min_child_weight': 6, 'gamma': 1.8593923495443399, 'lambda': 0.2815396579907953, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 1, 'group_season': 0, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 1, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 0, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 1, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 0, 'feature_month': 1, 'feature_day': 1, 'feature_hour': 1}. Best is trial 1 with value: 2.783324445499681.
# Optimizing:   4%|▍         | 2/50 [00:02<01:01,  1.27s/it][I 2024-10-18 14:24:46,926] Trial 2 finished with value: 2.2823647821731976 and parameters: {'n_estimators': 734, 'max_depth': 3, 'learning_rate': 0.2402178086782047, 'subsample': 0.6266781234712117, 'colsample_bytree': 0.7819006425701401, 'min_child_weight': 3, 'gamma': 0.40335979157804347, 'lambda': 2.876454961418744, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:   6%|▌         | 3/50 [00:04<01:08,  1.46s/it][I 2024-10-18 14:24:47,831] Trial 3 finished with value: 3.0832351599881327 and parameters: {'n_estimators': 360, 'max_depth': 4, 'learning_rate': 0.2615403278908319, 'subsample': 0.910758738588509, 'colsample_bytree': 0.505190955070228, 'min_child_weight': 6, 'gamma': 0.2641634255232872, 'lambda': 2.7849845680885785, 'group_day_of_week': 0, 'group_is_weekend': 0, 'group_month': 0, 'group_year': 1, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 0, 'feature_demand_production_ratio': 1, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 0, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 0, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 0, 'feature_Max_Wind': 0, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 0, 'feature_Snow_Depth': 0, 'feature_year': 0, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:   8%|▊         | 4/50 [00:05<00:56,  1.24s/it][I 2024-10-18 14:24:50,297] Trial 4 finished with value: 3.946962386586489 and parameters: {'n_estimators': 958, 'max_depth': 3, 'learning_rate': 0.175986613379434, 'subsample': 0.5961929220647205, 'colsample_bytree': 0.889775304955145, 'min_child_weight': 1, 'gamma': 0.21521814683336304, 'lambda': 2.98258204014791, 'group_day_of_week': 1, 'group_is_weekend': 0, 'group_month': 0, 'group_year': 0, 'group_season': 0, 'feature_volume_demand': 0, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 0, 'feature_demand_production_ratio': 1, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 1, 'feature_month_sin': 1, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 1, 'feature_price_boxcox': 0, 'feature_coal_price': 0, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 0, 'feature_Snow_Depth': 0, 'feature_year': 1, 'feature_month': 0, 'feature_day': 0, 'feature_hour': 1}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  10%|█         | 5/50 [00:07<01:15,  1.68s/it][I 2024-10-18 14:24:52,263] Trial 5 finished with value: 2.5108573285725013 and parameters: {'n_estimators': 911, 'max_depth': 6, 'learning_rate': 0.16248903175072157, 'subsample': 0.9971740706424039, 'colsample_bytree': 0.7195298393167169, 'min_child_weight': 5, 'gamma': 2.732226608378872, 'lambda': 0.36789237880985426, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 0, 'group_year': 1, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 0, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 0, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 0, 'feature_Snow_Depth': 0, 'feature_year': 0, 'feature_month': 1, 'feature_day': 0, 'feature_hour': 1}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  12%|█▏        | 6/50 [00:09<01:18,  1.78s/it][I 2024-10-18 14:24:53,291] Trial 6 finished with value: 2.4789065284195453 and parameters: {'n_estimators': 362, 'max_depth': 3, 'learning_rate': 0.09958172999112126, 'subsample': 0.5730155967834557, 'colsample_bytree': 0.7934987705653019, 'min_child_weight': 7, 'gamma': 1.1199186842011777, 'lambda': 0.753720827514815, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 0, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 0, 'feature_year': 1, 'feature_month': 1, 'feature_day': 0, 'feature_hour': 1}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  14%|█▍        | 7/50 [00:10<01:05,  1.53s/it][I 2024-10-18 14:24:54,793] Trial 7 finished with value: 2.8086495376141247 and parameters: {'n_estimators': 391, 'max_depth': 8, 'learning_rate': 0.02744986527995629, 'subsample': 0.7821573233472545, 'colsample_bytree': 0.9361040313937867, 'min_child_weight': 10, 'gamma': 3.889455767673615, 'lambda': 4.3331627628788425, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 0, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 1, 'feature_Max_Wind': 1, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 0, 'feature_Snow_Depth': 0, 'feature_year': 1, 'feature_month': 1, 'feature_day': 1, 'feature_hour': 0}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  16%|█▌        | 8/50 [00:12<01:03,  1.52s/it][I 2024-10-18 14:24:56,553] Trial 8 finished with value: 5.847852133227343 and parameters: {'n_estimators': 589, 'max_depth': 7, 'learning_rate': 0.1786222216278031, 'subsample': 0.5869835858172997, 'colsample_bytree': 0.5616558207441091, 'min_child_weight': 10, 'gamma': 1.9005831296970144, 'lambda': 4.307885490771916, 'group_day_of_week': 0, 'group_is_weekend': 0, 'group_month': 1, 'group_year': 1, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 0, 'feature_demand_production_ratio': 1, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 0, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 1, 'feature_price_boxcox': 0, 'feature_coal_price': 1, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 0, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 0, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 0, 'feature_year': 1, 'feature_month': 1, 'feature_day': 0, 'feature_hour': 1}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  18%|█▊        | 9/50 [00:14<01:05,  1.60s/it][I 2024-10-18 14:24:58,611] Trial 9 finished with value: 3.4543388302167353 and parameters: {'n_estimators': 450, 'max_depth': 5, 'learning_rate': 0.0262732224020828, 'subsample': 0.5868037837961093, 'colsample_bytree': 0.5005652573457714, 'min_child_weight': 6, 'gamma': 2.0915073679016087, 'lambda': 4.7435929850149785, 'group_day_of_week': 1, 'group_is_weekend': 0, 'group_month': 0, 'group_year': 1, 'group_season': 0, 'feature_volume_demand': 0, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 1, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 1, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 1, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 1, 'feature_Max_Wind': 0, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 0, 'feature_month': 1, 'feature_day': 0, 'feature_hour': 1}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  20%|██        | 10/50 [00:16<01:09,  1.74s/it][I 2024-10-18 14:25:00,151] Trial 10 finished with value: 3.1966139893317402 and parameters: {'n_estimators': 694, 'max_depth': 5, 'learning_rate': 0.23382369275917023, 'subsample': 0.7153780443420824, 'colsample_bytree': 0.9888348940456352, 'min_child_weight': 2, 'gamma': 4.979121434558518, 'lambda': 1.5959255577167637, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 0, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 0, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 0, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 1, 'feature_Max_Wind': 0, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 2 with value: 2.2823647821731976.
# Optimizing:  22%|██▏       | 11/50 [00:17<01:05,  1.68s/it][I 2024-10-18 14:25:02,016] Trial 11 finished with value: 2.2199714224601763 and parameters: {'n_estimators': 765, 'max_depth': 3, 'learning_rate': 0.09554931506523612, 'subsample': 0.7054407797864598, 'colsample_bytree': 0.7968317635956264, 'min_child_weight': 4, 'gamma': 0.904288206989852, 'lambda': 1.6812901737368455, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  24%|██▍       | 12/50 [00:19<01:05,  1.74s/it][I 2024-10-18 14:25:03,927] Trial 12 finished with value: 2.82460543556248 and parameters: {'n_estimators': 778, 'max_depth': 3, 'learning_rate': 0.09979022752011715, 'subsample': 0.7154415349412172, 'colsample_bytree': 0.7216025742680243, 'min_child_weight': 3, 'gamma': 1.0140906601502815, 'lambda': 1.8079574737826878, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  26%|██▌       | 13/50 [00:21<01:06,  1.79s/it][I 2024-10-18 14:25:05,823] Trial 13 finished with value: 2.2260877344594308 and parameters: {'n_estimators': 769, 'max_depth': 5, 'learning_rate': 0.10217055615949942, 'subsample': 0.8127448722907469, 'colsample_bytree': 0.7888102726040022, 'min_child_weight': 4, 'gamma': 0.9236129842469931, 'lambda': 1.8731429815119915, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  28%|██▊       | 14/50 [00:23<01:05,  1.82s/it][I 2024-10-18 14:25:08,002] Trial 14 finished with value: 4.030346822302003 and parameters: {'n_estimators': 827, 'max_depth': 5, 'learning_rate': 0.11933326341879136, 'subsample': 0.8239490792900119, 'colsample_bytree': 0.6580840477615981, 'min_child_weight': 4, 'gamma': 1.1747923001875686, 'lambda': 1.7970218578820594, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 0, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  30%|███       | 15/50 [00:25<01:07,  1.93s/it][I 2024-10-18 14:25:09,655] Trial 15 finished with value: 2.6935852970652236 and parameters: {'n_estimators': 619, 'max_depth': 6, 'learning_rate': 0.06313270027144276, 'subsample': 0.8487205274125522, 'colsample_bytree': 0.839731218828456, 'min_child_weight': 8, 'gamma': 3.3087572122228814, 'lambda': 1.0055511051087647, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  32%|███▏      | 16/50 [00:27<01:02,  1.85s/it][I 2024-10-18 14:25:10,192] Trial 16 finished with value: 2.344155689707679 and parameters: {'n_estimators': 118, 'max_depth': 4, 'learning_rate': 0.12131121286159077, 'subsample': 0.693455216102507, 'colsample_bytree': 0.805258590380968, 'min_child_weight': 4, 'gamma': 0.8827720899126653, 'lambda': 2.281624517188524, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  34%|███▍      | 17/50 [00:27<00:47,  1.45s/it][I 2024-10-18 14:25:12,439] Trial 17 finished with value: 2.7314095332333213 and parameters: {'n_estimators': 856, 'max_depth': 4, 'learning_rate': 0.07866833013993581, 'subsample': 0.9066307733080534, 'colsample_bytree': 0.6575645277905338, 'min_child_weight': 1, 'gamma': 1.3806142158382386, 'lambda': 3.518559489241207, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  36%|███▌      | 18/50 [00:29<00:54,  1.69s/it][I 2024-10-18 14:25:14,397] Trial 18 finished with value: 4.1316141921404395 and parameters: {'n_estimators': 688, 'max_depth': 7, 'learning_rate': 0.06424784406684284, 'subsample': 0.773819371353534, 'colsample_bytree': 0.7336404466873794, 'min_child_weight': 4, 'gamma': 2.893245669253303, 'lambda': 1.252100446736559, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 0, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 0, 'feature_demand_production_ratio': 1, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 0, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 0, 'feature_coal_price': 1, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 0, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 1, 'feature_Max_Wind': 0, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  38%|███▊      | 19/50 [00:31<00:54,  1.77s/it][I 2024-10-18 14:25:15,931] Trial 19 finished with value: 2.516760436451633 and parameters: {'n_estimators': 508, 'max_depth': 10, 'learning_rate': 0.1428303624275204, 'subsample': 0.6682370447106043, 'colsample_bytree': 0.907188606260846, 'min_child_weight': 8, 'gamma': 0.5841032710539783, 'lambda': 2.2976988345748217, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  40%|████      | 20/50 [00:33<00:51,  1.70s/it][I 2024-10-18 14:25:18,240] Trial 20 finished with value: 2.3158281218873977 and parameters: {'n_estimators': 988, 'max_depth': 4, 'learning_rate': 0.1895174167368981, 'subsample': 0.8334424173456625, 'colsample_bytree': 0.9788972911615728, 'min_child_weight': 3, 'gamma': 1.5539379110019405, 'lambda': 3.623974965247355, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  42%|████▏     | 21/50 [00:35<00:54,  1.88s/it][I 2024-10-18 14:25:20,265] Trial 21 finished with value: 2.308566103241479 and parameters: {'n_estimators': 772, 'max_depth': 3, 'learning_rate': 0.2194231796486396, 'subsample': 0.6436653474341438, 'colsample_bytree': 0.7878956835320431, 'min_child_weight': 3, 'gamma': 0.49935183381001347, 'lambda': 2.155547961593503, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  44%|████▍     | 22/50 [00:37<00:53,  1.93s/it][I 2024-10-18 14:25:22,348] Trial 22 finished with value: 2.2775113509258738 and parameters: {'n_estimators': 701, 'max_depth': 5, 'learning_rate': 0.29864292066386205, 'subsample': 0.7428522159465082, 'colsample_bytree': 0.7701572553730278, 'min_child_weight': 5, 'gamma': 0.022888560852305395, 'lambda': 3.4755263579630187, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  46%|████▌     | 23/50 [00:39<00:53,  1.97s/it][I 2024-10-18 14:25:24,239] Trial 23 finished with value: 2.418941510240864 and parameters: {'n_estimators': 646, 'max_depth': 6, 'learning_rate': 0.1378754788446713, 'subsample': 0.7493609812116001, 'colsample_bytree': 0.6853906673219468, 'min_child_weight': 5, 'gamma': 0.15961364057794203, 'lambda': 3.4665824975731643, 'group_day_of_week': 0, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 1, 'feature_volume_production': 1, 'feature_price_lag_1d': 1, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 1, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 0, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 0, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 1, 'feature_month_sin': 0, 'feature_month_cos': 1, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 0, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 1, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 1, 'feature_Fill_Level': 1, 'feature_Precipitation': 0, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  48%|████▊     | 24/50 [00:41<00:50,  1.95s/it][I 2024-10-18 14:25:25,920] Trial 24 finished with value: 2.2834111987007892 and parameters: {'n_estimators': 533, 'max_depth': 5, 'learning_rate': 0.05319412381676956, 'subsample': 0.7568521016691097, 'colsample_bytree': 0.8369285747959483, 'min_child_weight': 5, 'gamma': 0.7768895951650758, 'lambda': 1.2495994910999566, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# ...
# Optimizing:  86%|████████▌ | 43/50 [01:17<00:11,  1.66s/it][I 2024-10-18 14:26:00,921] Trial 43 finished with value: 2.2422846603741093 and parameters: {'n_estimators': 367, 'max_depth': 7, 'learning_rate': 0.10733532157877115, 'subsample': 0.799109619213073, 'colsample_bytree': 0.89283267374597, 'min_child_weight': 4, 'gamma': 1.3424900903659651, 'lambda': 1.9656992397276936, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  88%|████████▊ | 44/50 [01:18<00:08,  1.49s/it][I 2024-10-18 14:26:02,044] Trial 44 finished with value: 2.295268113950841 and parameters: {'n_estimators': 411, 'max_depth': 8, 'learning_rate': 0.11017748757072038, 'subsample': 0.8000109448185798, 'colsample_bytree': 0.8967191359057815, 'min_child_weight': 4, 'gamma': 1.8082022679050904, 'lambda': 1.9696597199081425, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  90%|█████████ | 45/50 [01:19<00:06,  1.38s/it][I 2024-10-18 14:26:02,877] Trial 45 finished with value: 2.334924283181463 and parameters: {'n_estimators': 281, 'max_depth': 8, 'learning_rate': 0.13540730512202132, 'subsample': 0.7385424681236163, 'colsample_bytree': 0.923833493104689, 'min_child_weight': 4, 'gamma': 2.287849001559035, 'lambda': 1.778134178706764, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  92%|█████████▏| 46/50 [01:20<00:04,  1.22s/it][I 2024-10-18 14:26:04,128] Trial 46 finished with value: 3.44196581736675 and parameters: {'n_estimators': 319, 'max_depth': 7, 'learning_rate': 0.10460889617262463, 'subsample': 0.7830052594878194, 'colsample_bytree': 0.8749306588956132, 'min_child_weight': 3, 'gamma': 1.319506500212613, 'lambda': 2.1105966579609103, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 0, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 0, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 1}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  94%|█████████▍| 47/50 [01:21<00:03,  1.23s/it][I 2024-10-18 14:26:04,854] Trial 47 finished with value: 2.5249927514466686 and parameters: {'n_estimators': 143, 'max_depth': 9, 'learning_rate': 0.0735909686517506, 'subsample': 0.8247574716660753, 'colsample_bytree': 0.9681547757477357, 'min_child_weight': 6, 'gamma': 1.7414669740214537, 'lambda': 4.804705712760093, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 0, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 0, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 1, 'feature_production_rolling_mean_7d': 1, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 0, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 1, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 0, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 0, 'feature_Max_Gust': 0, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 1, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  96%|█████████▌| 48/50 [01:22<00:02,  1.08s/it][I 2024-10-18 14:26:06,139] Trial 48 finished with value: 2.550089834381375 and parameters: {'n_estimators': 437, 'max_depth': 7, 'learning_rate': 0.09036399649000823, 'subsample': 0.7065443483474612, 'colsample_bytree': 0.8446253909243192, 'min_child_weight': 5, 'gamma': 1.0730372967364499, 'lambda': 1.3940995577334134, 'group_day_of_week': 1, 'group_is_weekend': 0, 'group_month': 1, 'group_year': 0, 'group_season': 0, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 1, 'feature_price_lag_30d': 0, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 1, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 1, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 0, 'feature_production_rolling_std_30d': 1, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 0, 'feature_Precipitation': 1, 'feature_Max_Temp': 1, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 1, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing:  98%|█████████▊| 49/50 [01:23<00:01,  1.14s/it][I 2024-10-18 14:26:06,862] Trial 49 finished with value: 2.2840660014262726 and parameters: {'n_estimators': 219, 'max_depth': 8, 'learning_rate': 0.12760766129188086, 'subsample': 0.8620090728026679, 'colsample_bytree': 0.7858284429209308, 'min_child_weight': 4, 'gamma': 1.3774434302716325, 'lambda': 2.362920499956421, 'group_day_of_week': 1, 'group_is_weekend': 1, 'group_month': 1, 'group_year': 1, 'group_season': 1, 'feature_volume_demand': 0, 'feature_volume_production': 0, 'feature_price_lag_1d': 0, 'feature_price_lag_7d': 0, 'feature_price_lag_30d': 1, 'feature_price_rolling_mean_7d': 0, 'feature_price_rolling_std_7d': 0, 'feature_price_rolling_mean_30d': 0, 'feature_price_rolling_std_30d': 1, 'feature_demand_production_ratio': 0, 'feature_demand_lag_1d': 1, 'feature_production_lag_1d': 0, 'feature_demand_rolling_mean_7d': 1, 'feature_demand_rolling_std_7d': 1, 'feature_demand_rolling_mean_30d': 0, 'feature_demand_rolling_std_30d': 0, 'feature_production_rolling_mean_7d': 0, 'feature_production_rolling_std_7d': 1, 'feature_production_rolling_mean_30d': 1, 'feature_production_rolling_std_30d': 0, 'feature_price_change_1d': 0, 'feature_month_sin': 1, 'feature_month_cos': 0, 'feature_price_ewm_alpha_0.5': 1, 'feature_demand_ewm_alpha_0.5': 1, 'feature_production_ewm_alpha_0.5': 0, 'feature_price_anomaly': 0, 'feature_price_boxcox': 1, 'feature_coal_price': 0, 'feature_crude_oil_price': 1, 'feature_natural_gas_price': 0, 'feature_Fill_Level': 1, 'feature_Precipitation': 1, 'feature_Max_Temp': 0, 'feature_Avg_Temp': 1, 'feature_Min_Temp': 0, 'feature_Max_Wind': 1, 'feature_Max_Gust': 1, 'feature_Avg_Wind': 1, 'feature_Snow_Depth': 1, 'feature_year': 1, 'feature_month': 0, 'feature_day': 1, 'feature_hour': 0}. Best is trial 11 with value: 2.2199714224601763.
# Optimizing: 100%|██████████| 50/50 [01:24<00:00,  1.69s/it]
# Best trial RMSE: 2.2199714224601763
#
# Best hyperparameters:
# {'colsample_bytree': 0.7968317635956264,
#  'feature_Avg_Temp': 1,
#  'feature_Avg_Wind': 1,
#  'feature_Fill_Level': 1,
#  'feature_Max_Gust': 1,
#  'feature_Max_Temp': 1,
#  'feature_Max_Wind': 1,
#  'feature_Min_Temp': 0,
#  'feature_Precipitation': 1,
#  'feature_Snow_Depth': 1,
#  'feature_coal_price': 0,
#  'feature_crude_oil_price': 1,
#  'feature_day': 1,
#  'feature_demand_ewm_alpha_0.5': 1,
#  'feature_demand_lag_1d': 1,
#  'feature_demand_production_ratio': 0,
#  'feature_demand_rolling_mean_30d': 0,
#  'feature_demand_rolling_mean_7d': 1,
#  'feature_demand_rolling_std_30d': 0,
#  'feature_demand_rolling_std_7d': 1,
#  'feature_hour': 0,
#  'feature_month': 0,
#  'feature_month_cos': 0,
#  'feature_month_sin': 1,
#  'feature_natural_gas_price': 0,
#  'feature_price_anomaly': 0,
#  'feature_price_boxcox': 1,
#  'feature_price_change_1d': 0,
#  'feature_price_ewm_alpha_0.5': 1,
#  'feature_price_lag_1d': 0,
#  'feature_price_lag_30d': 1,
#  'feature_price_lag_7d': 1,
#  'feature_price_rolling_mean_30d': 0,
#  'feature_price_rolling_mean_7d': 0,
#  'feature_price_rolling_std_30d': 1,
#  'feature_price_rolling_std_7d': 1,
#  'feature_production_ewm_alpha_0.5': 1,
#  'feature_production_lag_1d': 1,
#  'feature_production_rolling_mean_30d': 1,
#  'feature_production_rolling_mean_7d': 1,
#  'feature_production_rolling_std_30d': 1,
#  'feature_production_rolling_std_7d': 1,
#  'feature_volume_demand': 0,
#  'feature_volume_production': 0,
#  'feature_year': 1,
#  'gamma': 0.904288206989852,
#  'group_day_of_week': 1,
#  'group_is_weekend': 1,
#  'group_month': 1,
#  'group_season': 1,
#  'group_year': 0,
#  'lambda': 1.6812901737368455,
#  'learning_rate': 0.09554931506523612,
#  'max_depth': 3,
#  'min_child_weight': 4,
#  'n_estimators': 765,
#  'subsample': 0.7054407797864598}
#
# Selected features: ['day_of_week_1', 'day_of_week_2', 'day_of_week_3', 'day_of_week_4', 'day_of_week_5', 'day_of_week_6', 'is_weekend_1', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12', 'season_Spring', 'season_Summer', 'season_Winter', 'price_lag_7d', 'price_lag_30d', 'price_rolling_std_7d', 'price_rolling_std_30d', 'demand_lag_1d', 'production_lag_1d', 'demand_rolling_mean_7d', 'demand_rolling_std_7d', 'production_rolling_mean_7d', 'production_rolling_std_7d', 'production_rolling_mean_30d', 'production_rolling_std_30d', 'month_sin', 'price_ewm_alpha_0.5', 'demand_ewm_alpha_0.5', 'production_ewm_alpha_0.5', 'price_boxcox', 'crude_oil_price', 'Fill_Level', 'Precipitation', 'Max_Temp', 'Avg_Temp', 'Max_Wind', 'Max_Gust', 'Avg_Wind', 'Snow_Depth', 'year', 'day']
