# %%
# Cell 1: Import libraries and load data
import pandas as pd
import numpy as np
from flaml import AutoML
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Load the data
df = pd.read_csv('Datasets/data_NO2.csv', sep=';', parse_dates=['datetime_utc'])

# Keep only datetime and spot_price columns
df = df[['datetime_utc', 'spot_price']]

# Set datetime_utc as index
df.set_index('datetime_utc', inplace=True)

# Sort the index to ensure chronological order
df.sort_index(inplace=True)

# Resample to hourly frequency
df = df.resample('h').mean()

# Fill any missing values (if any) with forward fill
df = df.ffill()

print(df.head())

# Cell 2: Prepare data for forecasting
# Define the forecast horizon (24*7 = 168 hours)
forecast_horizon = 168

# Split the data into train and test sets
train_size = len(df) - forecast_horizon
train_df = df[:train_size]
test_df = df[train_size:]

# Prepare X and y for FLAML
X_train = train_df.index.values
y_train = train_df['spot_price'].values

X_test = test_df.index.values

print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)

# Cell 3: Set up and run FLAML AutoML
automl = AutoML()

# Set up the AutoML run
automl_settings = {
    "time_budget": 1800,  # in seconds
    "metric": 'mae',
    "task": 'ts_forecast',
    "log_file_name": "flaml_automl.log",
    "eval_method": "holdout",
    "period": forecast_horizon,
    "estimator_list": ['lgbm', 'xgboost', 'xgb_limitdepth', 'rf', 'extra_tree', 'prophet', 'arima', 'sarimax', 'holt-winters'],
}

# Fit the AutoML model
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)

# Print the best model and its hyperparameters
print("Best model:", automl.best_estimator)
print("Best hyperparameters:", automl.best_config)

# Cell 4: Make predictions and evaluate
# Make predictions
y_pred = automl.predict(X_test)

# Calculate MAE
mae = mean_absolute_error(test_df['spot_price'].values, y_pred)
print(f"Mean Absolute Error: {mae:.2f}")


# Cell 5: Visualize results
plt.figure(figsize=(12, 6))
plt.plot(test_df.index, test_df['spot_price'].values, label='Actual')
plt.plot(test_df.index, y_pred, label='Predicted')
plt.title('Spot Price Forecast')
plt.xlabel('Date')
plt.ylabel('Spot Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                            spot_price
# datetime_utc
# 2015-12-31 23:00:00+00:00       16.39
# 2016-01-01 00:00:00+00:00       16.04
# 2016-01-01 01:00:00+00:00       15.74
# 2016-01-01 02:00:00+00:00       15.57
# 2016-01-01 03:00:00+00:00       15.47
# Training data shape: (23500,)
# Test data shape: (168,)
# [flaml.automl.logger: 10-27 13:21:05] {1728} INFO - task = ts_forecast
# [flaml.automl.logger: 10-27 13:21:05] {1739} INFO - Evaluation method: holdout
# [flaml.automl.logger: 10-27 13:21:05] {1838} INFO - Minimizing error metric: mae
# [flaml.automl.logger: 10-27 13:21:05] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'xgboost', 'xgb_limitdepth', 'rf', 'extra_tree', 'prophet', 'arima', 'sarimax', 'holt-winters']
# [flaml.automl.logger: 10-27 13:21:05] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 10-27 13:21:25] {2393} INFO - Estimated sufficient time budget=193238s. Estimated necessary time budget=193s.
# [flaml.automl.logger: 10-27 13:21:25] {2442} INFO -  at 19.3s,	estimator lgbm's best error=19.9837,	best estimator lgbm's best error=19.9837
# [flaml.automl.logger: 10-27 13:21:25] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 10-27 13:22:26] {2442} INFO -  at 80.9s,	estimator lgbm's best error=19.9837,	best estimator lgbm's best error=19.9837
# [flaml.automl.logger: 10-27 13:22:26] {2258} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 10-27 13:22:40] {2442} INFO -  at 94.7s,	estimator xgboost's best error=19.9188,	best estimator xgboost's best error=19.9188
# [flaml.automl.logger: 10-27 13:22:40] {2258} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 10-27 13:22:54] {2442} INFO -  at 108.6s,	estimator xgboost's best error=19.9188,	best estimator xgboost's best error=19.9188
# [flaml.automl.logger: 10-27 13:22:54] {2258} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 10-27 13:22:57] {2442} INFO -  at 112.1s,	estimator lgbm's best error=13.1690,	best estimator lgbm's best error=13.1690
# [flaml.automl.logger: 10-27 13:22:57] {2258} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 10-27 13:23:03] {2442} INFO -  at 117.6s,	estimator lgbm's best error=8.2024,	best estimator lgbm's best error=8.2024
# [flaml.automl.logger: 10-27 13:23:03] {2258} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 10-27 13:23:45] {2442} INFO -  at 159.2s,	estimator lgbm's best error=8.2024,	best estimator lgbm's best error=8.2024
# [flaml.automl.logger: 10-27 13:23:45] {2258} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 10-27 13:23:48] {2442} INFO -  at 162.6s,	estimator lgbm's best error=8.2024,	best estimator lgbm's best error=8.2024
# [flaml.automl.logger: 10-27 13:23:48] {2258} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 10-27 13:24:56] {2442} INFO -  at 231.0s,	estimator lgbm's best error=6.4671,	best estimator lgbm's best error=6.4671
# [flaml.automl.logger: 10-27 13:24:56] {2258} INFO - iteration 9, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:25:19] {2442} INFO -  at 253.8s,	estimator xgb_limitdepth's best error=2.7358,	best estimator xgb_limitdepth's best error=2.7358
# [flaml.automl.logger: 10-27 13:25:19] {2258} INFO - iteration 10, current learner rf
# [flaml.automl.logger: 10-27 13:27:22] {2442} INFO -  at 376.5s,	estimator rf's best error=5.6918,	best estimator xgb_limitdepth's best error=2.7358
# [flaml.automl.logger: 10-27 13:27:22] {2258} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 10-27 13:28:18] {2442} INFO -  at 433.0s,	estimator extra_tree's best error=7.0535,	best estimator xgb_limitdepth's best error=2.7358
# [flaml.automl.logger: 10-27 13:28:18] {2258} INFO - iteration 12, current learner prophet
# 13:28:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:37 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:28:37] {2442} INFO -  at 451.6s,	estimator prophet's best error=2.0647,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:28:37] {2258} INFO - iteration 13, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:28:58] {2442} INFO -  at 473.0s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:28:58] {2258} INFO - iteration 14, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:29:19] {2442} INFO -  at 493.7s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:29:19] {2258} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 10-27 13:29:30] {2442} INFO -  at 504.2s,	estimator extra_tree's best error=7.0535,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:29:30] {2258} INFO - iteration 16, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:29:35] {2442} INFO -  at 509.2s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:29:35] {2258} INFO - iteration 17, current learner prophet
# 13:29:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:57 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:29:58] {2442} INFO -  at 532.2s,	estimator prophet's best error=2.0647,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:29:58] {2258} INFO - iteration 18, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:30:42] {2442} INFO -  at 576.5s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:30:42] {2258} INFO - iteration 19, current learner prophet
# 13:30:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:58 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:30:58] {2442} INFO -  at 592.6s,	estimator prophet's best error=2.0647,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:30:58] {2258} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 10-27 13:31:12] {2442} INFO -  at 606.2s,	estimator xgboost's best error=14.0886,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:31:12] {2258} INFO - iteration 21, current learner prophet
# 13:31:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:35 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:31:35] {2442} INFO -  at 629.4s,	estimator prophet's best error=2.0647,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:31:35] {2258} INFO - iteration 22, current learner extra_tree
# [flaml.automl.logger: 10-27 13:34:22] {2442} INFO -  at 796.7s,	estimator extra_tree's best error=7.0535,	best estimator prophet's best error=2.0647
# [flaml.automl.logger: 10-27 13:34:22] {2258} INFO - iteration 23, current learner prophet
# 13:34:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:38 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:34:38] {2442} INFO -  at 812.5s,	estimator prophet's best error=1.9844,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:34:38] {2258} INFO - iteration 24, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:36:00] {2442} INFO -  at 894.6s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:36:00] {2258} INFO - iteration 25, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:36:04] {2442} INFO -  at 899.2s,	estimator xgb_limitdepth's best error=2.7358,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:36:04] {2258} INFO - iteration 26, current learner prophet
# 13:36:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:18 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:36:18] {2442} INFO -  at 912.8s,	estimator prophet's best error=1.9844,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:36:18] {2258} INFO - iteration 27, current learner prophet
# 13:36:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:36 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:36:36] {2442} INFO -  at 930.9s,	estimator prophet's best error=1.9844,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:36:36] {2258} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 10-27 13:36:44] {2442} INFO -  at 938.6s,	estimator extra_tree's best error=7.0535,	best estimator prophet's best error=1.9844
# [flaml.automl.logger: 10-27 13:36:44] {2258} INFO - iteration 29, current learner prophet
# 13:36:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:05 - cmdstanpy - INFO - Chain [1] done processing
# [flaml.automl.logger: 10-27 13:37:05] {2442} INFO -  at 959.6s,	estimator prophet's best error=1.9757,	best estimator prophet's best error=1.9757
# [flaml.automl.logger: 10-27 13:37:05] {2258} INFO - iteration 30, current learner arima
# [flaml.automl.logger: 10-27 13:38:22] {2442} INFO -  at 1036.7s,	estimator arima's best error=0.6700,	best estimator arima's best error=0.6700
# [flaml.automl.logger: 10-27 13:38:22] {2258} INFO - iteration 31, current learner sarimax
# [flaml.automl.logger: 10-27 13:43:25] {2442} INFO -  at 1339.6s,	estimator sarimax's best error=0.6893,	best estimator arima's best error=0.6700
# [flaml.automl.logger: 10-27 13:43:25] {2258} INFO - iteration 32, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:43:28] {2442} INFO -  at 1342.3s,	estimator holt-winters's best error=0.7202,	best estimator arima's best error=0.6700
# [flaml.automl.logger: 10-27 13:43:28] {2258} INFO - iteration 33, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:43:28] {2442} INFO -  at 1342.7s,	estimator holt-winters's best error=0.7202,	best estimator arima's best error=0.6700
# [flaml.automl.logger: 10-27 13:43:28] {2258} INFO - iteration 34, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:43:30] {2442} INFO -  at 1345.0s,	estimator holt-winters's best error=0.7202,	best estimator arima's best error=0.6700
# [flaml.automl.logger: 10-27 13:43:30] {2258} INFO - iteration 35, current learner sarimax
# [flaml.automl.logger: 10-27 13:50:21] {2442} INFO -  at 1755.7s,	estimator sarimax's best error=0.6688,	best estimator sarimax's best error=0.6688
# [flaml.automl.logger: 10-27 13:50:21] {2258} INFO - iteration 36, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:50:23] {2442} INFO -  at 1757.9s,	estimator holt-winters's best error=0.7202,	best estimator sarimax's best error=0.6688
# [flaml.automl.logger: 10-27 13:50:23] {2258} INFO - iteration 37, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:50:26] {2442} INFO -  at 1760.4s,	estimator holt-winters's best error=0.7202,	best estimator sarimax's best error=0.6688
# [flaml.automl.logger: 10-27 13:50:26] {2258} INFO - iteration 38, current learner holt-winters
# Regressors are ignored for Holt-Winters ETS models.
# [flaml.automl.logger: 10-27 13:50:35] {2442} INFO -  at 1769.8s,	estimator holt-winters's best error=0.6817,	best estimator sarimax's best error=0.6688
# [flaml.automl.logger: 10-27 13:50:35] {2258} INFO - iteration 39, current learner xgb_limitdepth
# [flaml.automl.logger: 10-27 13:51:15] {2442} INFO -  at 1809.2s,	estimator xgb_limitdepth's best error=2.7358,	best estimator sarimax's best error=0.6688
# [flaml.automl.logger: 10-27 13:58:02] {2685} INFO - retrain sarimax for 407.7s
# [flaml.automl.logger: 10-27 13:58:02] {2688} INFO - retrained model: <statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper object at 0x167764590>
# [flaml.automl.logger: 10-27 13:58:02] {1985} INFO - fit succeeded
# [flaml.automl.logger: 10-27 13:58:02] {1986} INFO - Time taken to find the best model: 1755.6950221061707
# Best model: sarimax
# Best hyperparameters: {'p': 7, 'd': 0, 'q': 7, 'P': 2, 'D': 1, 'Q': 1, 's': 8, 'monthly_fourier_degree': 4, 'fourier_time_features': 1, 'pca_features': False}
# Mean Absolute Error: 2.20

# %%
import os
os.system('say "Wallah min bror! Din maskinlæringsmodell er klar. In god may your predictions be goated and the MAE low!"')
# Out:
# 0
